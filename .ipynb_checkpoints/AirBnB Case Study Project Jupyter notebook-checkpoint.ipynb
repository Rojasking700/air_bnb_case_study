# %% [markdown]
# # AirBnB NY Locations Data Case Study
#
# In this final project, you task will be to take the data provided and find evidence to answer the following questions.
#
# 1. Which hosts are the busiest and why?
# 2. How many neighborhood groups are available and which shows up the most?
# 3. Are private rooms the most popular in manhattan?
# 4. Which hosts are the busiest and based on their reviews?
# 5. Which neighorhood group has the highest average price?
# 6. Which neighborhood group has the highest total price?
# 7. Which top 5 hosts have the highest total price?
# 8. Who currently has no (zero) availability with a review count of 100 or more?
# 9. What host has the highest total of prices and where are they located?
# 10. When did Danielle from Queens last receive a review?

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
air_bnb = pd.read_csv('files/AB_NYC_2019.csv')
air_bnb.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
air_bnb.describe()
# Out:
#                  id       host_id      latitude     longitude         price  \
# count  4.889500e+04  4.889500e+04  48895.000000  48895.000000  48895.000000
# mean   1.901714e+07  6.762001e+07     40.728949    -73.952170    152.720687
# std    1.098311e+07  7.861097e+07      0.054530      0.046157    240.154170
# min    2.539000e+03  2.438000e+03     40.499790    -74.244420      0.000000
# 25%    9.471945e+06  7.822033e+06     40.690100    -73.983070     69.000000
# 50%    1.967728e+07  3.079382e+07     40.723070    -73.955680    106.000000
# 75%    2.915218e+07  1.074344e+08     40.763115    -73.936275    175.000000
# max    3.648724e+07  2.743213e+08     40.913060    -73.712990  10000.000000
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# count    48895.000000       48895.000000       38843.000000
# mean         7.029962          23.274466           1.373221
# std         20.510550          44.550582           1.680442
# ...

# %%
data = pd.DataFrame.from_dict(air_bnb)
data.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
# Which hosts are the busiest and why?

air_bnb.groupby(['host_id','host_name']).sum().sort_values('calculated_host_listings_count', ascending = False)
# Out:
#                                    id     latitude    longitude  price  \
# host_id   host_name
# 219517861 Sonder (NYC)    10885561678  13316.25823 -24198.18856  82795
# 107434423 Blueground       7210036953   9451.60418 -17166.13165  70331
# 30283594  Kara             1611854192   4931.41347  -8952.50779  33581
# 137358866 Kazuya           3121544245   4197.55601  -7612.96008   4514
# 16098958  Jeremy & Laura   1581720858   3912.98277  -7101.94534  20060
# ...                               ...          ...          ...    ...
# 13543967  Paulina            32338134     40.72912    -73.95203    100
# 13541655  Michael             4455094     40.73014    -74.00754    159
# 13540183  Ashley             18297633     40.63676    -73.95033    150
# 13538150  Mariana            28484124     40.77054    -73.99305     97
# 274321313 Kat                36484087     40.76392    -73.99183    125
#
#                           minimum_nights  number_of_reviews  \
# host_id   host_name
# ...

# %%
# How many neighborhood groups are available and which shows up the most? air_bnb.groupby(['neighbourhood_group','availability_365']).count()

availabilty = air_bnb[air_bnb['availability_365'] < 365]
print(availabilty['neighbourhood_group'].count())
availabilty.groupby(['neighbourhood_group']).describe()
# Out:
# 47600
#                           id                                                   \
#                        count          mean           std      min         25%
# neighbourhood_group
# Bronx                 1037.0  2.275557e+07  1.020395e+07  44096.0  16162933.0
# Brooklyn             19651.0  1.823752e+07  1.079349e+07   3831.0   8762818.5
# Manhattan            21089.0  1.878287e+07  1.115049e+07   2595.0   9172192.0
# Queens                5462.0  2.175360e+07  1.033640e+07  12937.0  13958697.0
# Staten Island          361.0  2.161891e+07  1.039657e+07  42882.0  15797728.0
#
#                                                          host_id  \
#                             50%         75%         max    count
# neighbourhood_group
# Bronx                23859280.0  31896339.0  36442252.0   1037.0
# Brooklyn             18837073.0  27729053.5  36485057.0  19651.0
# Manhattan            19138221.0  29513311.0  36487245.0  21089.0
# ...

# %%
# Are private rooms the most popular in manhattan?

air_bnb.groupby(['neighbourhood_group','room_type']).describe().sort_values('room_type')
# Out:
#                                           id                              \
#                                        count          mean           std
# neighbourhood_group room_type
# Bronx               Entire home/apt    379.0  2.269787e+07  1.023938e+07
# Brooklyn            Entire home/apt   9559.0  1.730117e+07  1.105914e+07
# Manhattan           Entire home/apt  13199.0  1.866860e+07  1.137015e+07
# Queens              Entire home/apt   2096.0  2.112772e+07  1.065926e+07
# Staten Island       Entire home/apt    176.0  2.170833e+07  1.063075e+07
# Bronx               Private room       652.0  2.235896e+07  1.024345e+07
# Brooklyn            Private room     10132.0  1.894125e+07  1.053306e+07
# Manhattan           Private room      7982.0  1.880759e+07  1.082334e+07
# Queens              Private room      3372.0  2.197231e+07  1.018115e+07
# Staten Island       Private room       188.0  2.106201e+07  1.020021e+07
# ...

# %%
# Which hosts are the busiest and based on their reviews?
#airbnb/groupby('host_id', 'host_name']).number_of_reviews.sum().nlargest(10)
air_bnb.sort_values(by=['host_id','number_of_reviews'], )
# Out:
#              id                                               name    host_id  \
# 30604  23669201  Great Price: Williamsburg Brooklyn Loft off L ...       2438
# 2290    1101224                                         THE PUTNAM       2571
# 0          2539                 Clean & quiet apt home by the park       2787
# 13963  10593675  La Spezia room.  Clean, quiet and comfortable bed       2787
# 13583  10160215                               Torre del Lago Room.       2787
# ...         ...                                                ...        ...
# 48875  36478343                              Welcome all as family  274273284
# 48881  36481615                   Peaceful space in Greenpoint, BK  274298453
# 48884  36482783        Brooklyn Oasis in the heart of Williamsburg  274307600
# 48886  36483010                    Comfy 1 Bedroom in Midtown East  274311461
# 48888  36484087  Spacious Room w/ Private Rooftop, Central loca...  274321313
#
# ...

# %%
#Which neighorhood group has the highest average price?
#air_bnb.groupby('neighbourhood_group').price.mean().sort_values(ascending=False)

# %%
# Which neighbor hood group has the highest total price?
#air_bnb.groupby('neighbourhood_group').price.sum().sort_values(asending=False)

# %%
#Which top 5 hosts have the highest total price?
# air_bnb.groupb(['host_id','host_name']).price.sum().sort_values(ascending=False).nlargest(5)

# %%
# Who currently has no (zero) availability with a review count of 100 or more?

# air_bnb[(air_bnb['availabiluty_365'] ==0) & (air_bnb['numberofreviews'] >= 100)]
# air_bnb.query('availability ==0 and number of reviews >= 100')

# %%
# What host has the highest total of prices and where are they located?
#  air_bnb..groupby(['host_name','neighborhood']).price.sum().nlargest(5)

# %%
# When did Danielle from Queens last receive a review?

# air_bnb.query("host_name == 'Danille' and neighbourhood_group = 'Queens'").last_review.sort_values(ascending=False)

# %% [markdown]
# ## Further Questions
#
# 1. Which host has the most listings?

# %%
# air_bnb.groupby(['host_id','host_name']).id.count().nlargest(10)

# %% [markdown]
# 2. How many listings have completely open availability?

# %%
opens = air_bnb[air_bnb['availability_365'] == 0]
opens.describe()['availability_365']
# Out:
# count    17533.0
# mean         0.0
# std          0.0
# min          0.0
# 25%          0.0
# 50%          0.0
# 75%          0.0
# max          0.0
# Name: availability_365, dtype: float64

# %% [markdown]
# 3. What room_types have the highest review numbers?

# %%
#air_bnb.groupby('')

# %% [markdown]
# # Final Conclusion
#
# In this cell, write your final conclusion for each of the questions asked.
#
# Also, if you uncovered some more details that were not asked above, please discribe them here.
#
# -- Add your conclusion --

# %% [markdown]
# <h2>#1</h2><p>hello</p>
# <h2>#2</h2><p>there are 47600 available rooms all 5 groups are available. The neighbourhood group that shows up the most is Manhattan.</p>
# <h2>#3</h2><p>manhattan does have the highest number of private rooms</p>
# <h2>#4</h2><p>hello</p>
# <h2>#5</h2><p>hello</p>
# <h2>#6</h2><p>hello</p>
# <h2>#7</h2><p>hello</p>
# <h2>#8</h2><p>hello</p>
# <h2>#9</h2><p>hello</p>
# <h2>#10</h2><p>hello</p>
